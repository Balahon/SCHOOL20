# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.arange(0,10)
y = np.arange(0,10)*5 + 2

# %%
plt.scatter(x,y)
plt.grid() 
plt.show()

# %%
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10)
y = np.arange(-10,10)**2
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10)
y = np.arange(-10,10)**2
plt.scatter(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10,0.1)
y = np.sin(np.arange(-10,10,0.1))
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10,0.1)
y = np.cos(np.arange(-10,10,0.1))
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10,0.1)
y = np.tan(np.arange(-10,10,0.1))
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
x = np.arange(-10,10,0.1)
y = np.exp(np.arange(-10,10,0.1))
plt.plot(x,y)
plt.grid() 
plt.show()

# %%
import time
from IPython import display
for k in range(-50,50):
    x = np.arange(-10,10)
    y = np.arange(-10,10)*k
    plt.plot(x,y)
    display.display(plt.gcf())
    display.clear_output(wait=True)
    time.sleep(1)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [12], in <module>
#       7 display.display(plt.gcf())
#       8 display.clear_output(wait=True)
# ----> 9 time.sleep(1)
#
# KeyboardInterrupt:

# %% [markdown]
# Датасет

# %%
age = []
sex = []
bmi = []
children = []
smoke = []
region = []
charhes = []

# %%
with open("./dataset_home.txt",mode='r') as file:
    for human in file.readlines():
        age.append(int(human.split(',')[0]))
        
        if human.split(',')[1] == 'male':
            sex.append(1)
        else:
            sex.append(0)
        
        bmi.append(float(human.split(',')[2]))
        children.append(int(human.split(',')[3]))
        
        if human.split(',')[4] == 'yes':
            smoke.append(1)
        else:
            smoke.append(0)
        
        if human.split(',')[5] == 'northwest':
            region.append(0)
        elif human.split(',')[5] == 'northeast':
            region.append(1)
        elif human.split(',')[5] == 'southwest':
            region.append(2)
        elif human.split(',')[5] == 'southeast':
            region.append(3)   
        else:
            region.append(human.split(',')[5])   
        
        charhes.append(float(human.split(',')[6]))

# %%
region
# Out:
# [0,
#  1,
#  0,
#  1,
#  2,
#  2,
#  0,
#  3,
#  3,
#  0,
#  2,
#  2,
#  3,
#  1,
#  0,
#  3,
#  3,
#  1,
#  0,
#  1,
#  1,
#  3,
#  2,
#  1,
#  3,
#  3,
#  3,
#  0,
#  0,
#  2,
#  0,
#  2,
#  1,
#  0,
#  3,
#  2,
#  3,
#  1,
#  2,
#  0,
#  2,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  2,
#  3,
#  3,
#  2,
#  3,
#  0,
#  0,
#  2,
#  3,
#  1,
#  3,
#  3,
#  0,
#  1,
#  3,
#  1,
#  3,
#  3,
#  0,
#  2,
#  3,
#  0,
#  1,
#  1,
#  0,
#  2,
#  3,
#  2,
#  2,
#  3,
#  2,
#  1,
#  0,
#  0,
#  0,
#  2,
#  0,
#  3,
#  0,
#  3,
#  2,
#  3,
#  3,
#  2,
#  0,
#  2,
#  0,
#  2,
#  2,
#  1,
#  0,
#  3,
#  0,
#  0,
#  1,
#  3,
#  0,
#  1,
#  2,
#  0,
#  3,
#  3,
#  1,
#  0,
#  1,
#  3,
#  2,
#  2,
#  0,
#  1,
#  2,
#  3,
#  0,
#  0,
#  2,
#  0,
#  2,
#  1,
#  3,
#  1,
#  0,
#  2,
#  1,
#  3,
#  1,
#  0,
#  0,
#  1,
#  2,
#  0,
#  1,
#  1,
#  0,
#  0,
#  0,
#  0,
#  3,
#  0,
#  2,
#  0,
#  0,
#  0,
#  1,
#  3,
#  0,
#  2,
#  2,
#  1,
#  2,
#  0,
#  3,
#  1,
#  2,
#  0,
#  1,
#  3,
#  3,
#  2,
#  0,
# ...

# %%
age = np.array(age) #возраст
sex = np.array(sex) #пол
bmi = np.array(bmi) #кэф веса
children = np.array(children) #наличие детей
smoke = np.array(smoke) #курящ
region = np.array(region) #регион
charhes = np.array(charhes) #страховка

# %%
age.shape
# Out:
# (670,)

# %%
age.min(), age.max(), age.mean()
# Out:
# (18, 64, 38.37761194029851)

# %%
charhes.min(), charhes.max(), charhes.mean()
# Out:
# (1131.5066, 62592.87309, 12899.874326014924)

# %%
plt.scatter(charhes,age)

# %%
plt.scatter(np.log(charhes),age)

# %%
plt.scatter(np.log(charhes),bmi)

# %%
plt.scatter(charhes,children)

# %%
plt.bar(smoke,charhes)
# Out:
# <BarContainer object of 670 artists>

# %%
plt.hist(charhes)
# Out:
# (array([278., 188.,  74.,  38.,  19.,  29.,  24.,  15.,   3.,   2.]),
#  array([ 1131.5066  ,  7277.643249, 13423.779898, 19569.916547,
#         25716.053196, 31862.189845, 38008.326494, 44154.463143,
#         50300.599792, 56446.736441, 62592.87309 ]),
#  <BarContainer object of 10 artists>)

# %%
age[age<36].shape
# Out:
# (307,)

# %%
age[age>35][age[age>35]<56].shape # старше 35 и младше 56
# Out:
# (269,)

# %%
age[age>55].shape
# Out:
# (94,)

# %%
plt.scatter(charhes[age<36],bmi[age<36],label="x < 36")
plt.scatter(charhes[age>35][age[age>35]<56],bmi[age>35][age[age>35]<56],label="35 < x < 56")
plt.scatter(charhes[age>55],bmi[age>55],label="x > 55")
plt.legend()
plt.show()

# %%
plt.hist(bmi)
# Out:
# (array([ 27.,  80., 129., 153., 142.,  79.,  44.,  11.,   3.,   2.]),
#  array([16.815 , 20.4465, 24.078 , 27.7095, 31.341 , 34.9725, 38.604 ,
#         42.2355, 45.867 , 49.4985, 53.13  ]),
#  <BarContainer object of 10 artists>)

# %%
bmi[bmi<23].shape
# Out:
# (76,)

# %%
bmi[bmi>22][bmi[bmi>22]<38].shape
# Out:
# (550,)

# %%
bmi[bmi>37].shape
# Out:
# (88,)

# %%
plt.scatter(charhes[bmi<23],bmi[bmi<23],label="x < 23")
plt.scatter(charhes[bmi>22][bmi[bmi>22]<38],bmi[bmi>22][bmi[bmi>22]<38],label="22 < x < 38")
plt.scatter(charhes[bmi>37],bmi[bmi>37],label="x > 37")
plt.legend()
plt.show()

# %%
plt.scatter(charhes,age)

# %%
plt.scatter(charhes,smoke)
